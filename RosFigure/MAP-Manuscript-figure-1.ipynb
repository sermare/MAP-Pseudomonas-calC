# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('/Users/sergiomares/Desktop/Pseudomonas BlastN full length sequences aligned.fas',delimiter = ' ',header = None)
df1 = []

for line in df[0]:
    if len(line) == 468:
        df1.append(line)
df1 = pd.DataFrame(df1)

# %%
a = []

for sequence in df1[0]:
    a.append(list(sequence))
    
a = pd.DataFrame(a)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

counts = a.apply(lambda x: x.value_counts() / len(x)).transpose()

counts = a.apply(lambda x: x.value_counts() / len(x)).transpose()
fig = plt.figure()
plt.rcParams["figure.figsize"] = [50,10]
ax = fig.add_subplot()
counts.plot(ax=ax,kind='bar', width = 1, stacked=True, rot=0, edgecolor = "black")
vals = ax.get_yticks()
ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals], fontsize = 20)
plt.ylabel('Freq. (n = 467)', fontsize = 20)
ax.yaxis.grid(False)
plt.xticks(rotation = 90, fontsize= 1)
ax.set_axisbelow(True)
plt.legend(loc=2, prop={'size': 20})
fig.savefig('align_me_ba2by.png')
plt.show()
# Out:
# /var/folders/pj/0dd0rqzj219164nwyh4f2l580000gn/T/ipykernel_65120/50011591.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals], fontsize = 20)
